# %% [markdown]
# # ****Remote Job Data Analysis(Discriptive Analysis)****

# %% [markdown]
# # **Introduction**
# Remote work advocates pointed to a techno-utopian vision with little time wasted on commuting, and in which people work from anywhere they choose(any location).
# Despite this promise, remote work adoption remained low prior to the COVID-19 pandemic period.

# %% [markdown]
# ### Background
# The landscape of work has undergone a significant transformation over the past decade, with remote work emerging as a prominent and widespread trend. The COVID-19 pandemic acted as a catalyst, accelerating the adoption of remote work practices across various industries. As organizations adapted to the new normal, remote work evolved from being a temporary solution to a long-term strategic approach.
#
# Remote work offers numerous benefits, including increased flexibility, reduced commuting time, and access to a broader talent pool. However, it also presents challenges such as communication barriers, feelings of isolation, and difficulties in managing remote teams. To navigate these challenges and optimize remote work practices, it is essential to leverage data analysis to gain insights into remote job trends, employee productivity, satisfaction, and overall organizational performance.
#
# ### Objectives
# The primary objective of this project is to analyze remote job data using descriptive statistics to identify key trends and patterns. By examining various metrics related to remote work, such as employee satisfaction, productivity levels, and work-life balance, we aim to provide actionable recommendations that can help organizations enhance their remote work practices and policies.
#
# ### Scope
# This project focuses on the descriptive analysis of a dataset containing information about remote jobs. The analysis includes the following key components:
# - **Measures of Central Tendency**: Calculating the mean, median, and mode of key variables to identify central points.
# - **Measures of Dispersion**: Assessing the range, variance, and standard deviation to understand the spread of the data.
# - **Frequency Distributions**: Analyzing how often each value in the dataset occurs.
# - **Percentiles and Quartiles**: Understanding the distribution of data by dividing it into equal parts.
# - **Visualizations**: Creating charts, graphs, and histograms to present data in a visually appealing and easy-to-understand manner.
#
# ### Significance
# Descriptive analysis plays a crucial role in summarizing and understanding the main features of a dataset. By applying descriptive statistics to remote job data, we can uncover valuable insights that inform decision-making processes and drive improvements in remote work environments. This analysis can help organizations to identify factors that contribute to employee satisfaction and productivity, enabling them to create a more supportive and efficient remote work culture.
#
#
# # **Dataset Description**
#
# This dataset, sourced from Kaggle, provides insights into remote job satisfaction. It comprises various attributes that influence an employee's experience while working remotely.
#
# **Attributes**
#
# 1. **Employee_ID**: This is a unique identifier of each employee which identify each record of employee.
# 2. **Employment_Type**: This indicate and discribes the type of work been done by the employer.
# 3. **Hours_worked_Per_Week**: This is the estimation or agregate of work been done by the employee per week to identify their interest in remote job.
# 4. **Productivity_Score**: This also shows and mesure the impact of remote job on employee based on productivity, its problem solving abilities and its contributions to real world problems.
# 5. **Well_Being_Score**: This provide the well being status of each employee in the remote Job
#
# **Data Source**
# Kaggle
#
# **Purpose**
# This dataset aims to provide insights into the factors influencing remote job satisfaction, offering valuable information for employers, policymakers, and researchers.
#
#
# Here are some related works and resources on remote job data analysis:
#
# 1. **"Can Data Analysts Work Remotely? [2025 Guide]" by CareerFoundry**: This guide explores the feasibility of remote work for data analysts, highlighting the benefits and challenges of working remotely in the data analytics field.
#
# 2. **"Remote Data Analyst Jobs - Work from Home & Online"**: A comprehensive list of remote data analyst job opportunities, including job descriptions, salaries, and employment types.
#
# 3. **"Remote Data Analyst Jobs, Employment - Indeed"**: A collection of remote data analyst job listings on Indeed, showcasing various roles, requirements, and salary ranges.
#
# 4. **"Remote Work and Data Analysis: Trends and Insights"**: This article discusses the growing trend of remote work in data analysis, providing insights into how organizations are adapting to remote work practices.
#
# 5. **"The Impact of Remote Work on Data Analysis: A Case Study"**: A case study examining the effects of remote work on data analysis processes, productivity, and employee satisfaction.

# %% [markdown]
#  # **Importing needed libraries for Remote Job Analysis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("remote_work_productivity.csv")
df
# Out:
#      Employee_ID Employment_Type  Hours_Worked_Per_Week  Productivity_Score  \
# 0              1          Remote                     29                  75
# 1              2       In-Office                     45                  49
# 2              3          Remote                     34                  74
# 3              4          Remote                     25                  81
# 4              5          Remote                     50                  70
# ..           ...             ...                    ...                 ...
# 995          996          Remote                     33                  88
# 996          997          Remote                     33                  88
# 997          998       In-Office                     45                  74
# 998          999       In-Office                     57                  50
# 999         1000          Remote                     34                  80
#
#      Well_Being_Score
# 0                  78
# ...

# %% [markdown]
# # **Exploratory Data Analysis(EDA)**

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Employment_Type        1000 non-null   object
#  2   Hours_Worked_Per_Week  1000 non-null   int64
#  3   Productivity_Score     1000 non-null   int64
#  4   Well_Being_Score       1000 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 39.2+ KB

# %%
df.dtypes
# Out:
# Employee_ID               int64
# Employment_Type          object
# Hours_Worked_Per_Week     int64
# Productivity_Score        int64
# Well_Being_Score          int64
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# # Performing Feature Encoding Also called Feature Engineering

# %%
df_encoder = pd.get_dummies(df)
df_encoder
# Out:
#      Employee_ID  Hours_Worked_Per_Week  Productivity_Score  Well_Being_Score  \
# 0              1                     29                  75                78
# 1              2                     45                  49                47
# 2              3                     34                  74                89
# 3              4                     25                  81                84
# 4              5                     50                  70                74
# ..           ...                    ...                 ...               ...
# 995          996                     33                  88                82
# 996          997                     33                  88                73
# 997          998                     45                  74                61
# 998          999                     57                  50                52
# 999         1000                     34                  80                82
#
# ...

# %%
df_encoder.columns
# Out:
# Index(['Employee_ID', 'Hours_Worked_Per_Week', 'Productivity_Score',
#        'Well_Being_Score', 'Employment_Type_In-Office',
#        'Employment_Type_Remote'],
#       dtype='object')

# %%
# claculating the correlation coefficient between features
corr_matrix = df_encoder.corr()
corr_matrix
# Out:
#                            Employee_ID  Hours_Worked_Per_Week  \
# Employee_ID                   1.000000              -0.027052
# Hours_Worked_Per_Week        -0.027052               1.000000
# Productivity_Score            0.032728              -0.254549
# Well_Being_Score              0.008498              -0.251574
# Employment_Type_In-Office    -0.010387               0.597426
# Employment_Type_Remote        0.010387              -0.597426
#
#                            Productivity_Score  Well_Being_Score  \
# Employee_ID                          0.032728          0.008498
# Hours_Worked_Per_Week               -0.254549         -0.251574
# Productivity_Score                   1.000000          0.135163
# Well_Being_Score                     0.135163          1.000000
# Employment_Type_In-Office           -0.402885         -0.390199
# Employment_Type_Remote               0.402885          0.390199
#
#                            Employment_Type_In-Office  Employment_Type_Remote
# ...

# %% [markdown]
# # **Measures of Dispersion**
#
# * Presentation of the range, variance, and standard deviation of key variables to understand the spread of the data.

# %%
df_encoder.describe()
# Out:
#        Employee_ID  Hours_Worked_Per_Week  Productivity_Score  \
# count  1000.000000            1000.000000         1000.000000
# mean    500.500000              39.720000           68.602000
# std     288.819436               8.042779           12.235494
# min       1.000000              16.000000           33.000000
# 25%     250.750000              34.750000           60.000000
# 50%     500.500000              40.000000           68.000000
# 75%     750.250000              45.000000           76.000000
# max    1000.000000              64.000000          112.000000
#
#        Well_Being_Score
# count       1000.000000
# mean          63.975000
# std           13.870572
# min           14.000000
# 25%           56.000000
# 50%           65.000000
# 75%           73.000000
# max          104.000000

# %%
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm", linewidths=0.6)
plt.title("Correlation Between Features")
plt.show()

# %%
sns.heatmap(df_encoder.describe(), annot=True)
plt.title("description of Remote-work data")
plt.show()

# %%
# Bar chart for employment type
sns.barplot(x=df_encoder["Employment_Type_Remote"].value_counts().index, y=df_encoder["Employment_Type_In-Office"].value_counts().values)
# Out:
# <Axes: xlabel='Employment_Type_Remote'>

# %% [markdown]
# ***Almost Employment_Type is same so if there is differencial between both of the types it would be marginal.***

# %%
# Creating histograms for Hours_Worked_Per_Week, Productivity_Score, and Well_Being_Score
plt.figure(figsize=(20, 6))

# Histogram for Hours_Worked_Per_Week
plt.subplot(1, 3, 1)
sns.histplot(df_encoder['Hours_Worked_Per_Week'], kde=True)
plt.title('Distribution of Hours Worked Per Week')
plt.xlabel('Hours Worked Per Week')
plt.ylabel('Frequency')

# Histogram for Productivity_Score
plt.subplot(1, 3, 2)
sns.histplot(df_encoder['Productivity_Score'], kde=True)
plt.title('Distribution of Productivity Score')
plt.xlabel('Productivity Score')
plt.ylabel('Frequency')

# Histogram for Well_Being_Score
plt.subplot(1, 3, 3)
sns.histplot(df_encoder['Well_Being_Score'], kde=True)
plt.title('Distribution of Well Being Score')
plt.xlabel('Well Being Score')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# **The Interpretation of the result above**
#
# **1. Distribution of Hours Worked Per Week:**
#
# * This histogram shows the frequency distribution of the number of hours worked per week by remote employees where most distribution is around 40 hours which is quite normal for typical office hours or else working from home.
#
#
# **2. Distribution of Productivity Score:**
#
# * This histogram displays the frequency distribution of productivity scores among remote employees where maxminum productivity score has been acquired between 70 to 80 point.
#
#
# **3. Distribution of Well Being Score:**
#
# * This histogram illustrates the frequency distribution of well-being scores among remote employees. The distribution is slighly shown though but we can take insight from the ditribution group.

# %%
df_encoder.columns
# Out:
# Index(['Employee_ID', 'Hours_Worked_Per_Week', 'Productivity_Score',
#        'Well_Being_Score', 'Employment_Type_In-Office',
#        'Employment_Type_Remote'],
#       dtype='object')

# %%
df_encoder.dtypes
# Out:
# Employee_ID                  int64
# Hours_Worked_Per_Week        int64
# Productivity_Score           int64
# Well_Being_Score             int64
# Employment_Type_In-Office     bool
# Employment_Type_Remote        bool
# dtype: object

# %%
 # Create a scatter plot for Hours_Worked_Per_Week vs Productivity_Score
plt.figure(figsize=(20, 6))
sns.scatterplot(x='Hours_Worked_Per_Week', y='Productivity_Score', data=df_encoder)
plt.title('Relationship between Hours Worked Per Week and Productivity Score')
plt.xlabel('Hours Worked Per Week')
plt.ylabel('Productivity Score')
plt.show()

# %% [markdown]
# **No Strong Linear Relationship**:
#
#     - There doesn't seem to be a clear, straight line pattern between hours worked per week and productivity score. This suggests that the relationship between these two variables is more complex than a simple linear correlation.
#
# **Clustering**:
#
#     - There are noticeable clusters of data points, particularly around the middle of the x-axis (hours worked). This might indicate that there are groups of individuals or teams that tend to work similar hours and achieve similar productivity levels.
#
# **Outliers**:
#
#     - A few data points appear to be outliers, meaning they are significantly different from the general trend. These could represent individual cases or situations that are not representative of the overall relationship.
#
# **Potential for Other Factors**:
#
#     - The lack of a strong linear relationship suggests that other factors besides hours worked might be influencing productivity. These could include job type, individual differences, work environment, or organizational culture.

# %%
plt.figure(figsize=(20, 6))
sns.lineplot(x='Hours_Worked_Per_Week', y='Productivity_Score', data=df_encoder, hue='Employment_Type_In-Office')

plt.figure(figsize=(20, 6))
sns.lineplot(x='Hours_Worked_Per_Week', y='Productivity_Score', data=df_encoder, hue='Employment_Type_Remote')
# Out:
# <Axes: xlabel='Hours_Worked_Per_Week', ylabel='Productivity_Score'>

# %% [markdown]
# **Y-axis (Well_Being_Score):**
#
#     The range is approximately from 50 to 100, representing the Productivity_Score of employees.
#
# **X-axis (Employment_Type):**
#
#     Categories are represented: Number of Hours Worked Per Week.
#
# **Line Plot:**
#
#     A blue line shows a trend for remote job, indicating how the well productivity score varies for Hours Worked Per Week.
#
#     A orange line shows a trend for At office work, indicating how the well productivity score varies for Hours Worked Per Week.
#
# **Observations:**
#
#     Remote workers have a higher productivity score than WFO
#
#     In-office workers are having higher works per week.
#
# **Trend:**
#
#     The plot indicates a clear upward trend in remote job rather than working from office.
#
#     This visualization suggests that remote workers are associated with higher productivity scores compared to in-office workers, though there is some upwards trends when office worker can only achieve when they work more than 60 hours per week.

# %%
plt.figure(figsize=(20, 6))
sns.lineplot(x='Hours_Worked_Per_Week', y='Well_Being_Score', data=df_encoder, hue='Employment_Type_In-Office')

plt.figure(figsize=(20, 6))
sns.lineplot(x='Hours_Worked_Per_Week', y='Well_Being_Score', data=df_encoder, hue='Employment_Type_Remote')
# Out:
# <Axes: xlabel='Hours_Worked_Per_Week', ylabel='Well_Being_Score'>

# %% [markdown]
# **Y-axis (Well_Being_Score):**
#
#     The range is approximately from 40 to 90, representing the Well Being Score of employees.
#
# **X-axis (Employment_Type):**
#
#     Categories are represented: Number of Hours Worked Per Week.
#
# **Line Plot:**
#
#     A blue line shows a trend for remote job, indicating how the well being score varies for Hours Worked Per Week.
#
#     A orange line shows a trend for At office work, indicating how the well being score varies for Hours Worked Per Week.
#
# **Observations:**
#
#     Remote workers have a higher well being score than WFO, but under 30hours office work has higher well being, which is normal weekday for employee who is working from office.
#
#     In-office workers are having higher hours works per week.
#
# **Trend:**
#
#     The plot indicates a clear upward trend in remote job rather than working from office for well being score.
#
#     This visualization suggests that remote workers are associated with higher well being scores compared to in-office workers, though there is some upwards trends when office worker can only achieve if they work under 30 hours.

# %%
plt.figure(figsize=(20, 6))
sns.scatterplot(x='Productivity_Score', y='Well_Being_Score', data=df_encoder)
plt.title('Relationship between Hours Worked Per Week and Productivity Score')
plt.xlabel('Hours Worked Per Week')
plt.ylabel('Productivity Score')
plt.show()

# %% [markdown]
# **No Strong Linear Relationship**:
#
#     - There doesn't seem to be a clear, straight line pattern between hours worked per week and productivity score. This suggests that the relationship between these two variables is more complex than a simple linear correlation.
#
# **Clustering**:
#
#     - There are noticeable clusters of data points, particularly around the Middle of the x-axis (hours worked). This might indicate that there are groups of individuals or teams that tend to work similar hours and achieve similar productivity levels within the range of 60 hours to 80 hours.
# **Outliers**:
#
#     - A few data points appear to be outliers, meaning they are significantly different from the general trend. These could represent individual cases or situations that are not
#     representative of the overall relationship.
#
# **Potential for Other Factors**:
#
#     - The lack of a strong linear relationship suggests that other factors besides hours worked might be influencing productivity. These could include job type, individual differences, work environment, or organizational culture.

# %%
#Make two empty list for numeric and object data
#save numeric data into num empty list
num= []
cat = []

#iterate through dataset and save different dtypes in different list
for col in df_encoder.columns:

    #take help of api to save numeric data into an empty list
    if pd.api.types.is_numeric_dtype(df_encoder[col]):
        num.append(col)
    else:
        cat.append(col)

#Print empty list
print(num)
print(cat)
# Out:
# ['Employee_ID', 'Hours_Worked_Per_Week', 'Productivity_Score', 'Well_Being_Score', 'Employment_Type_In-Office', 'Employment_Type_Remote']
# []

# %%
#Multiple plot of numeric columns.

for i in num:

    #Iterate through all the data values 
    figure,axes = plt.subplots(1,2,figsize=(15,5))
    sns.histplot(df_encoder[i],ax=axes[0],kde=True)
    axes[0].set_title(f"Hist distribution{i}")
    axes[0].grid(True)
    axes[0].set_xlabel(" ")

    #box plot
    sns.boxplot(df_encoder[i],ax=axes[1])
    axes[1].set_title(f"Hist distribution{i}")
    axes[1].grid(True)
    axes[1].set_xlabel(" ")

# %% [markdown]
# **Insights**:
#
# **Outlier Analysis and Distribution**:
#
#     The histograms reveal a relatively uniform distribution of data points across all value ranges, indicating a lack of significant skewness or clustering. This observation is particularly useful for identifying outliers and understanding their prevalence within different segments.
#
#     By analyzing the outliers, we can gain valuable insights into potential anomalies, exceptional cases, or data entry errors that might be affecting the overall data quality. This information can be used to refine data cleaning processes, improve data accuracy, and enhance the reliability of subsequent analyses.

# %%
corr = df_encoder.select_dtypes(include=['int','float']).corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(20, 15))
sns.clustermap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()


plt.figure(figsize=(20, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ***Correlation Matrix***
#  - There is positive relation with
#     - Employee ID -- Well_Being_Score
#     - Employee ID -- Productivity Score
#     - Well_Beign_Score -- Productivity Score
#
# ***The rest other features are having negative correlation with each other.***

# %%
# Select the relevant columns for correlation
relevant_data = df_encoder[['Hours_Worked_Per_Week', 'Productivity_Score', 'Well_Being_Score']]

# Compute the correlation matrix
corr_matrix = relevant_data.corr()

# Plot the heatmap
plt.figure(figsize=(20, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix for Hours Worked, Productivity Score, and Well Being Score')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot histograms for numerical columns
numerical_cols = df_encoder.select_dtypes(include=['float64', 'int64']).columns
for col in numerical_cols:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], kde=True, color='c')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.title(f'Distribution of {col}')
    plt.show()

# %% [markdown]
# # **Modeling**

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = df_encoder.drop(columns=['Employee_ID' , 'Productivity_Score'])
y = df_encoder['Productivity_Score']

# %%
x_train, x_test, y_train, y_test=train_test_split(x , y , test_size=0.2 , random_state=42)

# %%
model = LinearRegression()
model.fit(x_train , y_train);

# %%
y_preds = model.predict(X_test)
y_preds[:5]
# Out:
# array([73.36182462, 73.65037887, 73.85856075, 63.65086702, 63.55969632])

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
MSE = mean_squared_error(Y_test, y_preds)
MSE
# Out:
# 112.79215081276139

# %%
R2 = r2_score(y_test , y_preds)
R2
# Out:
# 0.187786053051333

# %% [markdown]
# # Logistic Regression

# %%
accuracies={}

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
lr = LogisticRegression(penalty='l2')
lr.fit(x_train,y_train)

y_pred = lr.predict(x_test)

acc=accuracy_score(y_test,y_pred)
accuracies['Logistic Regression']=acc*100
print("Accuracy score of the model is:",accuracy_score(y_test,y_pred)*100,"%")
# Out:
# Accuracy score of the model is: 3.5000000000000004 %

# %% [markdown]
# # KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=8)

knn.fit(x_train,y_train)

y_pred1 = knn.predict(x_test)

acc1=accuracy_score(y_test,y_pred)
accuracies['KNeighborsClassifier']=acc1*100

accuracy_score(y_train,knn.predict(x_train))
print("Accuracy score of the model is:",accuracy_score(y_test,y_pred1)*100,"%")
# Out:
# Accuracy score of the model is: 0.5 %

# %% [markdown]
#  # SVM

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)

y_pred2 = svc.predict(x_test)

acc2=accuracy_score(y_test,y_pred2)
accuracies['SVC']=acc2*100

accuracy_score(y_train,svc.predict(x_train))

print("Accuracy score of the model is:",accuracy_score(y_test,y_pred2)*100,"%")
# Out:
# Accuracy score of the model is: 3.0 %

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)

y_pred3 = dtc.predict(x_test)
acc3=accuracy_score(y_test,y_pred)
accuracies['DecisionTreeClassifier']=acc3*100

accuracy_score(y_train,dtc.predict(x_train))
print("Accuracy score of the model is:",accuracy_score(y_test,y_pred3)*100,"%")
# Out:
# Accuracy score of the model is: 4.5 %

# %%
from sklearn.model_selection import GridSearchCV

grid_params = {
    'criterion' : ['gini', 'entropy'],
    'max_depth' : [3, 5, 7, 10],
    'min_samples_split' : range(2, 10, 1),
    'min_samples_leaf' : range(2, 10, 1)
}

grid_search = GridSearchCV(dtc, grid_params, cv = 5, n_jobs = -1, verbose = 1)
grid_search.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 512 candidates, totalling 2560 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 5, 7, 10],
#                          'min_samples_leaf': range(2, 10),
#                          'min_samples_split': range(2, 10)},
#              verbose=1)

# %% [markdown]
# **Hyperparameter Tuning:** The primary purpose of the above code is to find the best combination of hyperparameters for the decision tree classifier. Hyperparameters control the behavior of the machine learning algorithm, and tuning them can significantly improve the model's performance.

# %%
grid_search.best_score_
# Out:
# 0.045

# %%
y_pred4 = dtc.predict(x_test)
acc4=accuracy_score(y_test,y_pred4)
accuracies['DecisionTreeClassifier']=acc4*100
print("Accuracy score of the model is:",accuracy_score(y_test,y_pred4)*100,"%")
# Out:
# Accuracy score of the model is: 4.5 %

# %% [markdown]
# **Trying with more than one Estimators**

# %%
np.random.seed(43)
for i in range (10, 110, 10):
    print(f"Trying the model with {i} estimators")
    clf=RandomForestClassifier(n_estimators=i).fit(x_train, y_train)
    print(f"The accuracy of the model is :{clf.score(x_test, y_test)*100:.2f}%")
    print("")
# Out:
# Trying the model with 10 estimators
# The accuracy of the model is :3.00%
#
# Trying the model with 20 estimators
# The accuracy of the model is :3.50%
#
# Trying the model with 30 estimators
# The accuracy of the model is :3.50%
#
# Trying the model with 40 estimators
# The accuracy of the model is :4.00%
#
# Trying the model with 50 estimators
# The accuracy of the model is :3.50%
#
# Trying the model with 60 estimators
# The accuracy of the model is :3.00%
#
# Trying the model with 70 estimators
# The accuracy of the model is :3.50%
#
# Trying the model with 80 estimators
# The accuracy of the model is :3.00%
#
# Trying the model with 90 estimators
# The accuracy of the model is :3.50%
#
# Trying the model with 100 estimators
# The accuracy of the model is :3.50%

# %% [markdown]
#  # Result Of diffrent Estimators(Models) listed below:
#
#  * Linear Regression has 0.18%
#  * Logistic Rgression has 3.18%
#  * KNeighbors Classifier has 0.5%
#  * SVM has 3.0%
#  * Decision Tree has 4.5%
